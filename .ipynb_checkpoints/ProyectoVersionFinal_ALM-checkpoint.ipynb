# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataSet= np.load('proyecto_training_data.npy')

# %%
dataSet= pd.DataFrame(dataSet)
dataSet
# Out:
#              0    1       2    3       4     5
# 0     208500.0  7.0   856.0  8.0  2003.0  65.0
# 1     181500.0  6.0  1262.0  6.0  1976.0  80.0
# 2     223500.0  7.0   920.0  6.0  2001.0  68.0
# 3     140000.0  7.0   961.0  7.0  1915.0  60.0
# 4     250000.0  8.0  1145.0  9.0  2000.0  84.0
# ...        ...  ...     ...  ...     ...   ...
# 1455  175000.0  6.0   953.0  7.0  1999.0  62.0
# 1456  210000.0  6.0  2073.0  7.0  1978.0  85.0
# 1457  266500.0  7.0  1188.0  9.0  1941.0  66.0
# 1458  142125.0  5.0  1078.0  5.0  1950.0  68.0
# 1459  147500.0  5.0  1256.0  6.0  1965.0  75.0
#
# [1460 rows x 6 columns]

# %%
dataSet= pd.DataFrame(dataSet)
dataSet.columns=['SalePrice','OverallQual','1stFlrSF','TotRmsAbvGrd','YearBuilt','LotFrontage']
dataSet
#dataSet.query('SalePrice==@Max')
# Out:
#       SalePrice  OverallQual  1stFlrSF  TotRmsAbvGrd  YearBuilt  LotFrontage
# 0      208500.0          7.0     856.0           8.0     2003.0         65.0
# 1      181500.0          6.0    1262.0           6.0     1976.0         80.0
# 2      223500.0          7.0     920.0           6.0     2001.0         68.0
# 3      140000.0          7.0     961.0           7.0     1915.0         60.0
# 4      250000.0          8.0    1145.0           9.0     2000.0         84.0
# ...         ...          ...       ...           ...        ...          ...
# 1455   175000.0          6.0     953.0           7.0     1999.0         62.0
# 1456   210000.0          6.0    2073.0           7.0     1978.0         85.0
# 1457   266500.0          7.0    1188.0           9.0     1941.0         66.0
# 1458   142125.0          5.0    1078.0           5.0     1950.0         68.0
# 1459   147500.0          5.0    1256.0           6.0     1965.0         75.0
#
# [1460 rows x 6 columns]

# %%
e_ntrenamiento = 0.80
dataSet['is_train'] = np.random.uniform(0, 1, len(dataSet)) <= e_ntrenamiento
entrenamiento, validacion = dataSet[dataSet['is_train']==True], dataSet[dataSet['is_train']==False]
dataSet = dataSet.drop('is_train', 1)
print ("Entrenamiento",len(entrenamiento))
print("Validacion",len(validacion))
print(entrenamiento)
# Out:
# Entrenamiento 1174
# Validacion 286
#       SalePrice  OverallQual  1stFlrSF  TotRmsAbvGrd  YearBuilt  LotFrontage  \
# 1      181500.0          6.0    1262.0           6.0     1976.0         80.0
# 2      223500.0          7.0     920.0           6.0     2001.0         68.0
# 3      140000.0          7.0     961.0           7.0     1915.0         60.0
# 4      250000.0          8.0    1145.0           9.0     2000.0         84.0
# 5      143000.0          5.0     796.0           5.0     1993.0         85.0
# ...         ...          ...       ...           ...        ...          ...
# 1455   175000.0          6.0     953.0           7.0     1999.0         62.0
# 1456   210000.0          6.0    2073.0           7.0     1978.0         85.0
# 1457   266500.0          7.0    1188.0           9.0     1941.0         66.0
# 1458   142125.0          5.0    1078.0           5.0     1950.0         68.0
# 1459   147500.0          5.0    1256.0           6.0     1965.0         75.0
#
#       is_train
# 1         True
# 2         True
# 3         True
# 4         True
# 5         True
# ...        ...
# 1455      True
# 1456      True
# 1457      True
# 1458      True
# 1459      True
#
# [1174 rows x 7 columns]
# C:\Users\analu\AppData\Local\Temp\ipykernel_14656\2081137301.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   dataSet = dataSet.drop('is_train', 1)

# %%
entrenamiento
# Out:
#       SalePrice  OverallQual  1stFlrSF  TotRmsAbvGrd  YearBuilt  LotFrontage  \
# 1      181500.0          6.0    1262.0           6.0     1976.0         80.0
# 2      223500.0          7.0     920.0           6.0     2001.0         68.0
# 3      140000.0          7.0     961.0           7.0     1915.0         60.0
# 4      250000.0          8.0    1145.0           9.0     2000.0         84.0
# 5      143000.0          5.0     796.0           5.0     1993.0         85.0
# ...         ...          ...       ...           ...        ...          ...
# 1455   175000.0          6.0     953.0           7.0     1999.0         62.0
# 1456   210000.0          6.0    2073.0           7.0     1978.0         85.0
# 1457   266500.0          7.0    1188.0           9.0     1941.0         66.0
# 1458   142125.0          5.0    1078.0           5.0     1950.0         68.0
# 1459   147500.0          5.0    1256.0           6.0     1965.0         75.0
#
#       is_train
# 1         True
# 2         True
# 3         True
# 4         True
# 5         True
# ...        ...
# 1455      True
# 1456      True
# 1457      True
# 1458      True
# 1459      True
#
# [1174 rows x 7 columns]

# %%
#MEDIA POR VARIABLES
mediaS=np.median(entrenamiento['SalePrice'])
mediaO=np.median(entrenamiento['OverallQual'])
media1=np.median(entrenamiento['1stFlrSF'])
mediaT=np.median(entrenamiento['TotRmsAbvGrd'])
mediaY=np.median(entrenamiento['YearBuilt'])
mediaL=np.median(entrenamiento['LotFrontage'])
#muestra resultado de media
    #print('Media_SalePrice       ',str(mediaS))
    #print('Media_OverallQual     ', str(mediaO))
    #print('Media_1stFlrSF        ', str(media1))
    #print('Media_TotRmsAbvGrd    ', str(mediaT))
    #print('Media_YearBuilt       ', str(mediaY))
    #print('Media_LotFrontage     ', str(mediaL))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SalePrice'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14656\3641697194.py in <module>
#       1 entrenamiento
#       2 #MEDIA POR VARIABLES
# ----> 3 mediaS=np.median(entrenamiento['SalePrice'])
#       4 mediaO=np.median(entrenamiento['OverallQual'])
#       5 media1=np.median(entrenamiento['1stFlrSF'])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'SalePrice'

# %%
#VALORES MAXIMOS POR VARIABLES
MaxS=np.max(entrenamiento['SalePrice'])
MaxO=np.max(entrenamiento['OverallQual'])
Max1=np.max(entrenamiento['1stFlrSF'])
MaxT=np.max(entrenamiento['TotRmsAbvGrd'])
MaxY=np.max(entrenamiento['YearBuilt'])
MaxL=np.max(entrenamiento['LotFrontage'])
#muestra resultado de max
    #print('Max_SalePrice       ',str(MaxS))
    #print('Max_OverallQual     ', str(MaxO))
    #print('Max_1stFlrSF        ', str(Max1))
    #print('Max_TotRmsAbvGrd    ', str(MaxT))
    #print('Max_YearBuilt       ', str(MaxY))
    #print('Max_LotFrontage     ', str(MaxL))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SalePrice'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17224\2608492093.py in <module>
#       1 #VALORES MAXIMOS POR VARIABLES
# ----> 2 MaxS=np.max(entrenamiento['SalePrice'])
#       3 MaxO=np.max(entrenamiento['OverallQual'])
#       4 Max1=np.max(entrenamiento['1stFlrSF'])
#       5 MaxT=np.max(entrenamiento['TotRmsAbvGrd'])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'SalePrice'

# %%
#VALORES MINIMOS POR VARIABLES
MinS=np.min(entrenamiento['SalePrice'])
MinO=np.min(entrenamiento['OverallQual'])
Min1=np.min(entrenamiento['1stFlrSF'])
MinT=np.min(entrenamiento['TotRmsAbvGrd'])
MinY=np.min(entrenamiento['YearBuilt'])
MinL=np.min(entrenamiento['LotFrontage'])
#muestra valores min
    #print('Min_SalePrice       ',str(MinS))
    #print('Min_OverallQual     ', str(MinO))
    #print('Min_1stFlrSF        ', str(Min1))
    #print('Min_TotRmsAbvGrd    ', str(MinT))
    #print('Min_YearBuilt       ', str(MinY))
    #print('Min_LotFrontage     ', str(MinL))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SalePrice'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17224\1779245872.py in <module>
#       1 #VALORES MINIMOS POR VARIABLES
# ----> 2 MinS=np.min(entrenamiento['SalePrice'])
#       3 MinO=np.min(entrenamiento['OverallQual'])
#       4 Min1=np.min(entrenamiento['1stFlrSF'])
#       5 MinT=np.min(entrenamiento['TotRmsAbvGrd'])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'SalePrice'

# %%
#RANGOS POR VARIABLE PEAK TO PEAK
ptpS=np.ptp(entrenamiento['SalePrice'])
ptpO=np.ptp(entrenamiento['OverallQual'])
ptp1=np.ptp(entrenamiento['1stFlrSF'])
ptpT=np.ptp(entrenamiento['TotRmsAbvGrd'])
ptpY=np.ptp(entrenamiento['YearBuilt'])
ptpL=np.ptp(entrenamiento['LotFrontage'])
#muestra valores peak to peak
    #print('Ptp_SalePrice       ',str(ptpS))
    #print('Ptp_OverallQual     ', str(ptpO))
    #print('Ptp_1stFlrSF        ', str(ptp1))
    #print('Ptp_TotRmsAbvGrd    ', str(ptpT))
    #print('Ptp_YearBuilt       ', str(ptpY))
    #print('Ptp_LotFrontage     ', str(ptpL))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SalePrice'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17224\3646529100.py in <module>
#       1 #RANGOS POR VARIABLE PEAK TO PEAK
# ----> 2 ptpS=np.ptp(entrenamiento['SalePrice'])
#       3 ptpO=np.ptp(entrenamiento['OverallQual'])
#       4 ptp1=np.ptp(entrenamiento['1stFlrSF'])
#       5 ptpT=np.ptp(entrenamiento['TotRmsAbvGrd'])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'SalePrice'

# %%
#DESVIACION ESTANDAR POR VARIABLE
stdS=np.std(entrenamiento['SalePrice'])
stdO=np.std(entrenamiento['OverallQual'])
std1=np.std(entrenamiento['1stFlrSF'])
stdT=np.std(entrenamiento['TotRmsAbvGrd'])
stdY=np.std(entrenamiento['YearBuilt'])
stdL=np.std(entrenamiento['LotFrontage'])
#muestra valores desviación estandar
    #print('std_SalePrice       ',str(stdS))
    #print('std_OverallQual     ', str(stdO))
    #print('std_1stFlrSF        ', str(std1))
    #print('std_TotRmsAbvGrd    ', str(stdT))
    #print('std_YearBuilt       ', str(stdY))
    #print('std_LotFrontage     ', str(stdL))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SalePrice'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17224\1634486946.py in <module>
#       1 #DESVIACION ESTANDAR POR VARIABLE
# ----> 2 stdS=np.std(entrenamiento['SalePrice'])
#       3 stdO=np.std(entrenamiento['OverallQual'])
#       4 std1=np.std(entrenamiento['1stFlrSF'])
#       5 stdT=np.std(entrenamiento['TotRmsAbvGrd'])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'SalePrice'

# %%
#Graficas Seaborn
#SalePrice
sns.displot(entrenamiento['SalePrice'])
sns.displot(entrenamiento['OverallQual'])
sns.displot(entrenamiento['1stFlrSF'])
sns.displot(entrenamiento['TotRmsAbvGrd'])
sns.displot(entrenamiento['YearBuilt'])
sns.displot(entrenamiento['LotFrontage'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SalePrice'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17224\2126142754.py in <module>
#       1 #Graficas Seaborn
#       2 #SalePrice
# ----> 3 sns.displot(entrenamiento['SalePrice'])
#       4 sns.displot(entrenamiento['OverallQual'])
#       5 sns.displot(entrenamiento['1stFlrSF'])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'SalePrice'

# %%
corre= pd.DataFrame(entrenamiento)
cols=[0,1,2,3,4,5]
correl= corre[corre.columns[cols]]
correl.corr()
# Out:
#           0         1         2         3         4         5
# 0  1.000000  0.791024  0.615559  0.540151  0.528235  0.372430
# 1  0.791024  1.000000  0.501398  0.438678  0.581803  0.265098
# 2  0.615559  0.501398  1.000000  0.416515  0.298353  0.471100
# 3  0.540151  0.438678  0.416515  1.000000  0.118606  0.349682
# 4  0.528235  0.581803  0.298353  0.118606  1.000000  0.142896
# 5  0.372430  0.265098  0.471100  0.349682  0.142896  1.000000

# %%
#CORRELACION DE VARIABLES X
#Se excluye la variable Y 
#corre= pd.DataFrame(entrenamiento)
#cols=[1,2,3,4,5]
#correl= corre[corre.columns[cols]]
#correl.corr()

#CORRELACION DE VARIABLES 
corre= pd.DataFrame(entrenamiento)
cols=[0,1,2,3,4,5]
correl= corre[corre.columns[cols]]
correl.corr()


#GRAFICA DE CORRELACION
plt.scatter(correl['SalePrice'],correl['OverallQual'])
plt.title('OverallQual vs SalePrice')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SalePrice'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17224\2762837411.py in <module>
#      14
#      15 #GRAFICA DE CORRELACION
# ---> 16 plt.scatter(correl['SalePrice'],correl['OverallQual'])
#      17 plt.title('OverallQual vs SalePrice')
#      18 plt.show()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'SalePrice'

# %%
plt.scatter(correl['SalePrice'],correl['1stFlrSF'])
plt.title('1stFlrSF vs SalePrice')
plt.show()

# %%
plt.scatter(correl['SalePrice'],correl['TotRmsAbvGrd'])
plt.title('TotRmsAbvGrd vs SalePrice')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SalePrice'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17224\3378310827.py in <module>
# ----> 1 plt.scatter(correl['SalePrice'],correl['TotRmsAbvGrd'])
#       2 plt.title('TotRmsAbvGrd vs SalePrice')
#       3 plt.show()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'SalePrice'

# %%
plt.scatter(correl['SalePrice'],correl['YearBuilt'])
plt.title('YearBuilt vs SalePrice')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SalePrice'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17224\1533595215.py in <module>
# ----> 1 plt.scatter(correl['SalePrice'],correl['YearBuilt'])
#       2 plt.title('YearBuilt vs SalePrice')
#       3 plt.show()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'SalePrice'

# %%
plt.scatter(correl['SalePrice'],correl['LotFrontage'])
plt.title('LotFrontage vs SalePrice')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SalePrice'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17224\3604123270.py in <module>
# ----> 1 plt.scatter(correl['SalePrice'],correl['LotFrontage'])
#       2 plt.title('LotFrontage vs SalePrice')
#       3 plt.show()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'SalePrice'

# %%
list [1,2,3],[1]
# Out:
# (list[1, 2, 3], [1])

# %%
def regresion(x, y, epochs, imprimir_error_cada, alpha):
    n = len(x)
    X = [[1, element] for element in x]
    beta = [0, 0] 
    errores = [] 
    for i in range(epochs):
        y_pred = [beta[0]*X[j][0] + beta[1]*X[j][1] for j in range(n)] 
        error = sum([(y[j]-y_pred[j])**2 for j in range(n)])/(2*n) 
        errores.append(error) 
        if i % imprimir_error_cada == 0: 
            print("Iteración:", i, "Error:", error)
        grad_beta = [(1/n)*sum([(y_pred[j]-y[j])*X[j][k] for j in range(n)]) for k in range(2)] 
        beta = [beta[k] - alpha*grad_beta[k] for k in range(2)] 
    return beta, errores

regresion([0,1,2],[3,4,5],7,1,10)
#se eligen las variables: yearBuilt y LotFrontage
#paso 6 y 7 del documento: Crear una función

#def regresion( x, y, epoch, imprimir_error_cada,escalar):
#    #creo matriz con 2 columnas una para los valores x y la segunda con valores 1
#    matx_col=[]
#    matx=[]
#    for element in x:
#        matx_col.append(1)
#        print (element)
#    matx = [x,matx_col]
#    print(matx)
#    i=0
#    ypred = np.dot(observacion, parametro)
#    while i < epoch:
#        print (i)
#        i=i+1
#    return 
#fin  de la funcion
# Out:
# Iteración: 0 Error: 8.333333333333334
# Iteración: 1 Error: 4112.037037037036
# Iteración: 2 Error: 2150750.7201646077
# Iteración: 3 Error: 1125338433.7562864
# Iteración: 4 Error: 588812754610.2128
# Iteración: 5 Error: 308085509575432.06
# Iteración: 6 Error: 1.6120011068932214e+17
# ([4914965673.964333, 6819150417.293092],
#  [8.333333333333334,
#   4112.037037037036,
#   2150750.7201646077,
#   1125338433.7562864,
#   588812754610.2128,
#   308085509575432.06,
#   1.6120011068932214e+17])
